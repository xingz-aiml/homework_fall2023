# %% [markdown]
# # Goal
#
# questions regarding the math derivations

# %%
## 1. the logic behind pi to pi(a|s)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 ## 1. the logic behind pi to pi(a|s)
# ----> 3 image.png
#
# NameError: name 'image' is not defined
